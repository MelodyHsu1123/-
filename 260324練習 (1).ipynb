# %%
print("Hello World")
# Out:
# Hello World

# %%
x=3
y=1.2
z="Hello World"
print("x=",x,type(x))
print("y=",y,type(y))
print("z=",z,type(z))
# Out:
# x= 3 <class 'int'>
# y= 1.2 <class 'float'>
# z= Hello World <class 'str'>

# %% [markdown]
# ### 程式實例ch3_24.py ：從地球到月球約是384400公里，假設火箭的速度是一馬赫，設計一個程式計算需要多少天、多少小時才可抵達月球。這個程式省略分鐘數.

# %%
# ch3_24.py
dist = 384400                      #地球到月亮的距離
speed = 1225                       #馬赫速度每小時1225公里
total_hours = dist // speed        #計算小時數
days = total_hours // 24           #商 = 計算天數
hours = total_hours % 24           #餘數 = 計算小時數
print("總共需要天數")
print(days)
print("小時數")
print(hours)
# Out:
# 總共需要天數
# 13
# 小時數
# 1

# %% [markdown]
# # 程式實例ch4_15.py：基本資料輸入與運算。

# %%
# ch4_15.py
print("歡迎使用成績輸入系統")
name = input("請輸入姓名:")
engh = input("請輸入英文成績:")
math = input("請輸入數學成績:")
chinese = input("請輸入國文成績:")
nature = input("請輸入自然成績:")
total = int(engh) + int(math) + int(chinese) + int(nature)
print("%s 你的總分是 %d" % (name, total))
# Out:
# 歡迎使用成績輸入系統
# 請輸入姓名: 王大頭
# 請輸入英文成績: 90
# 請輸入數學成績: 100
# 請輸入國文成績: 90
# 請輸入自然成績: 95
# 王大頭 你的總分是 375

# %% [markdown]
# # 程式實例ch4_16.py：請輸入華氏溫度，這個程式會輸出攝氏溫度。

# %%
# ch4_20.py
f = float(input("請輸入華氏溫度 : "))
c = ( f - 32 ) * 5 / 9
print("華氏 %4.1f 等於攝氏 %4.1f" % (f, c))
# Out:
# 請輸入華氏溫度 :  23
# 華氏 23.0 等於攝氏 -5.0

# %% [markdown]
# # 練習：判斷輸入的數字是否為3的倍數

# %%
# ch5_4.py
print("奇數偶數判斷")
num = input("請輸入任意整值：" )
rem = int(num) % 2
if (rem == 0):
    print("%d 是偶数" % int(num))
else:
    print("%d 是奇数" % int(num))
# Out:
# 奇數偶數判斷
# 請輸入任意整值： 3
# 3 是奇数
